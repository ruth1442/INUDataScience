# %%
#202101491 신서연

# %%
a = ["one","two","three"]
b = [[1,2],3,[4]]
d = {}
d = dict()

for i in range(len(a)):
    if a[i] not in d.keys():
        d[a[i]] = b[i]
    else:
        print("이미 있는 키입니다.")
print(d)
# Out:
# {'one': [1, 2], 'two': 3, 'three': [4]}

# %%
#202101491 신서연
